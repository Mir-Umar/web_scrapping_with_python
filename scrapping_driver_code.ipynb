# %%
#importing .py libraries
# !pip install -r requirements.txt
# !pip install wordcloud

# %%
import scrapping
# Out:
# C:\Users\93856\Anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
import os

DIR_PATH = "./DataScraped/NDG-Category/"
PRODUCT = 'OTG Cable'
BRAND = 'vetro'
PRODUCT_PATH = DIR_PATH + PRODUCT

if not os.path.exists(PRODUCT_PATH):
    os.makedirs(PRODUCT_PATH,exist_ok=True)

# %%
#Device specific headers at https://httpbin.org/get
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36 Edg/122.0.0.0"}

# exec_code(product, brand, time_limit, device_specific_headers)
df, brand_present_df = scrapping.exec_code(PRODUCT,BRAND,60,headers)

# %%
df = df[['querry_searched','ecommerce_website','product_name']]

# %%
print("Total number of products scrapped in 60 seconds are ", len(df))
# Out:
# Total number of products scrapped in 60 seconds are  48

# %%
df
# Out:
#     querry_searched ecommerce_website  \
# 0   Micro USB Cable            Amazon
# 1   Micro USB Cable            Amazon
# 2   Micro USB Cable            Amazon
# 3   Micro USB Cable            Amazon
# 4   Micro USB Cable            Amazon
# 5   Micro USB Cable            Amazon
# 6   Micro USB Cable            Amazon
# 7   Micro USB Cable            Amazon
# 8   Micro USB Cable            Amazon
# 9   Micro USB Cable            Amazon
# 10  Micro USB Cable            Amazon
# 11  Micro USB Cable            Amazon
# 12  Micro USB Cable            Amazon
# 13  Micro USB Cable            Amazon
# 14  Micro USB Cable            Amazon
# 15  Micro USB Cable            Amazon
# 16  Micro USB Cable            Amazon
# 17  Micro USB Cable            Amazon
# 18  Micro USB Cable            Amazon
# 19  Micro USB Cable            Amazon
# 20  Micro USB Cable            Amazon
# 21  Micro USB Cable            Amazon
# 22  Micro USB Cable            Amazon
# ...

# %%
df.to_csv(f"{PRODUCT_PATH}/{PRODUCT}.csv",index=False)

# %%
PRODUCT_PATH
# Out:
# './DataScraped/NDG-Category/USB C Cable'
